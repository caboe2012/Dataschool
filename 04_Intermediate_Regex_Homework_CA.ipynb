# %% [markdown]
# # Intermediate Regex Homework

# %% [markdown]
# ## UFO sightings
#
# The [ufo-reports](https://github.com/planetsig/ufo-reports) GitHub repository contains reports of UFO sightings downloaded from the [National UFO Reporting Center](http://www.nuforc.org/) website. One of the data fields is the **duration of the sighting**, which includes **free-form text**. These are some example entries:
#
# - 45 minutes
# - 1-2 hrs
# - 20 seconds
# - 1/2 hour
# - about 3 mins
# - several minutes
# - one hour?
# - 5min

# %% [markdown]
# Here is **how to read in the file:**
#
# - Use the pandas **`read_csv()`** function to read directly from this [URL](https://raw.githubusercontent.com/planetsig/ufo-reports/master/csv-data/ufo-scrubbed-geocoded-time-standardized.csv).
# - Use the **`header=None`** parameter to specify that the data does not have a header row.
# - Use the **`nrows=100`** parameter to specify that you only want to read in the first 100 rows.
# - Save the relevant Series as a Python list, just like we did in a class exercise.

# %%
# load the data into a pandas DF
import pandas as pd
URL = 'https://raw.githubusercontent.com/planetsig/ufo-reports/master/csv-data/ufo-scrubbed-geocoded-time-standardized.csv'
ufo = pd.read_csv(URL, header=None, nrows=100)

# %%
ufo.head()
# Out:
#                  0                     1    2    3         4     5   \
# 0  10/10/1949 20:30            san marcos   tx   us  cylinder  2700
# 1  10/10/1949 21:00          lackland afb   tx  NaN     light  7200
# 2  10/10/1955 17:00  chester (uk/england)  NaN   gb    circle    20
# 3  10/10/1956 21:00                  edna   tx   us    circle    20
# 4  10/10/1960 20:00               kaneohe   hi   us     light   900
#
#            6                                                  7           8   \
# 0  45 minutes  This event took place in early fall around 194...   4/27/2004
# 1     1-2 hrs  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2  20 seconds  Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3    1/2 hour  My older brother and twin sister were leaving ...   1/17/2004
# 4  15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
#
#           9           10
# 0  29.883056  -97.941111
# 1  29.384210  -98.581082
# 2  53.200000   -2.916667
# 3  28.978333  -96.645833
# 4  21.418056 -157.803611

# %% [markdown]
# Your assignment is to **normalize the duration data for the first 100 rows** by splitting each entry into two parts:
#
# - The first part should be a **number**: either a whole number (such as '45') or a decimal (such as '0.5').
# - The second part should be a **unit of time**: either 'hr' or 'min' or 'sec'
#
# The expected output is a **list of tuples**, containing the **original (unedited) string**, the **number**, and the **unit of time**. Here is a what the output should look like:
#
# > `clean_durations = [('45 minutes', '45', 'min'), ('1-2 hrs', '1', 'hr'), ('20 seconds', '20', 'sec'), ...]`

# %%
duration = ufo[6].tolist()

# %%
print type(duration)
# Out:
# <type 'list'>

# %%
import re

# %%
print duration
# Out:
# ['45 minutes', '1-2 hrs', '20 seconds', '1/2 hour', '15 minutes', '5 minutes', 'about 3 mins', '20 minutes', '3  minutes', 'several minutes', '5 min.', '3 minutes', '30 min.', '3 minutes', '30 seconds', '20minutes', '2 minutes', '20-30 min', '20 sec.', '45 minutes', '20 minutes', 'one hour?', '5-6 minutes', '1 minute', '3 seconds', '30 seconds', 'approx: 30 seconds', '5min', '15 minutes', '4.5 or more min.', '3 minutes', '30mins.', '3 min', '5 minutes', '3 to 5 min', '2min', '1 minute', 'couple minutes', '15-20 seconds', '10min', '3 minutes', '10 minutes', 'few minutes', '1 minute', '2 sec.', 'approx 5 min', '1 minute', '3min', '2 minutes', '30 minutes', '10 minutes', '1 hour(?)', '10 seconds', '1min. 39s', '30 seconds', '20 minutes', '8 seconds', 'less than 1 min', '1 hour', '2 minutes', '5 seconds', '~1 hour', '2 min.', '1 minute', '3sec', '5 min', '5 min', '1 minute', '4 hours', '30 seconds', '<5 minutes', '1-hour', '5 minutes', '10 to 15 sec', '30 +/- min', '10 minutes', '45min.', '< 1 min', '10 minutes', '2 seconds', '2 hours', '15 seconds', '1 hour', '5-10 min.', '10 seconds', '1 hour', '45 secs', '60-90 sec', '3 hours', '5 min', 'several minutes', '4 minutes', '45 minutes', '3 minutes', '10 seconds', '30seconds', '45 seconds', '15 seconds', '30 min.', '4-5 seconds']

# %%
# replace qualitative explanation of duration with numeric equivalent
clean_test = []
for each in test:
    updated = re.sub(r'several',r'5', each)
    updated = re.sub(r'couple|few', r'2', updated)
    updated = re.sub(r'1/2', r'0.5', updated)
    updated = re.sub(r'hours?', r'hr', updated)
    updated = re.sub(r'one', r'1', updated)
    match = re.search(r'([\d.]+).*(min|hr|sec)', updated)
    clean_test.append((each, match.group(1), match.group(2)))
clean_test
# Out:
# [('45 minutes', '45', 'min'),
#  ('1-2 hrs', '1', 'hr'),
#  ('20 seconds', '20', 'sec'),
#  ('1/2 hour', '0.5', 'hr'),
#  ('15 minutes', '15', 'min'),
#  ('5 minutes', '5', 'min'),
#  ('about 3 mins', '3', 'min'),
#  ('20 minutes', '20', 'min'),
#  ('3  minutes', '3', 'min'),
#  ('several minutes', '5', 'min'),
#  ('5 min.', '5', 'min'),
#  ('3 minutes', '3', 'min'),
#  ('30 min.', '30', 'min'),
#  ('3 minutes', '3', 'min'),
#  ('30 seconds', '30', 'sec'),
#  ('20minutes', '20', 'min'),
#  ('2 minutes', '2', 'min'),
#  ('20-30 min', '20', 'min'),
#  ('20 sec.', '20', 'sec'),
#  ('45 minutes', '45', 'min'),
#  ('20 minutes', '20', 'min'),
#  ('one hour?', '1', 'hr'),
#  ('5-6 minutes', '5', 'min'),
#  ('1 minute', '1', 'min'),
#  ('3 seconds', '3', 'sec'),
#  ('30 seconds', '30', 'sec'),
#  ('approx: 30 seconds', '30', 'sec'),
#  ('5min', '5', 'min'),
#  ('15 minutes', '15', 'min'),
#  ('4.5 or more min.', '4.5', 'min'),
#  ('3 minutes', '3', 'min'),
#  ('30mins.', '30', 'min'),
#  ('3 min', '3', 'min'),
#  ('5 minutes', '5', 'min'),
#  ('3 to 5 min', '3', 'min'),
#  ('2min', '2', 'min'),
#  ('1 minute', '1', 'min'),
#  ('couple minutes', '2', 'min'),
#  ('15-20 seconds', '15', 'sec'),
#  ('10min', '10', 'min'),
#  ('3 minutes', '3', 'min'),
#  ('10 minutes', '10', 'min'),
#  ('few minutes', '2', 'min'),
#  ('1 minute', '1', 'min'),
#  ('2 sec.', '2', 'sec'),
#  ('approx 5 min', '5', 'min'),
#  ('1 minute', '1', 'min'),
#  ('3min', '3', 'min'),
#  ('2 minutes', '2', 'min'),
#  ('30 minutes', '30', 'min'),
#  ('10 minutes', '10', 'min'),
#  ('1 hour(?)', '1', 'hr'),
#  ('10 seconds', '10', 'sec'),
#  ('1min. 39s', '1', 'min'),
#  ('30 seconds', '30', 'sec'),
#  ('20 minutes', '20', 'min'),
#  ('8 seconds', '8', 'sec'),
#  ('less than 1 min', '1', 'min'),
#  ('1 hour', '1', 'hr'),
#  ('2 minutes', '2', 'min'),
#  ('5 seconds', '5', 'sec'),
#  ('~1 hour', '1', 'hr'),
#  ('2 min.', '2', 'min'),
#  ('1 minute', '1', 'min'),
#  ('3sec', '3', 'sec'),
#  ('5 min', '5', 'min'),
#  ('5 min', '5', 'min'),
#  ('1 minute', '1', 'min'),
#  ('4 hours', '4', 'hr'),
#  ('30 seconds', '30', 'sec'),
#  ('<5 minutes', '5', 'min'),
#  ('1-hour', '1', 'hr'),
#  ('5 minutes', '5', 'min'),
#  ('10 to 15 sec', '10', 'sec'),
#  ('30 +/- min', '30', 'min'),
#  ('10 minutes', '10', 'min'),
#  ('45min.', '45', 'min'),
#  ('< 1 min', '1', 'min'),
#  ('10 minutes', '10', 'min'),
#  ('2 seconds', '2', 'sec'),
#  ('2 hours', '2', 'hr'),
#  ('15 seconds', '15', 'sec'),
#  ('1 hour', '1', 'hr'),
#  ('5-10 min.', '5', 'min'),
#  ('10 seconds', '10', 'sec'),
#  ('1 hour', '1', 'hr'),
#  ('45 secs', '45', 'sec'),
#  ('60-90 sec', '60', 'sec'),
#  ('3 hours', '3', 'hr'),
#  ('5 min', '5', 'min'),
#  ('several minutes', '5', 'min'),
#  ('4 minutes', '4', 'min'),
#  ('45 minutes', '45', 'min'),
#  ('3 minutes', '3', 'min'),
#  ('10 seconds', '10', 'sec'),
#  ('30seconds', '30', 'sec'),
#  ('45 seconds', '45', 'sec'),
#  ('15 seconds', '15', 'sec'),
#  ('30 min.', '30', 'min'),
#  ('4-5 seconds', '4', 'sec')]

# %%
clean_durations = []
for each in duration:
    re.sub(r'several',r'5', each)
    re.sub(r'couple' ,r'2', each)
    re.sub(r'one', r'1', each)
    try:
        current = re.search(r'(\d+) ([\w]+)', each)
#        current = re.search(r'(.*) ([\w]+)', each)
        print "ALL:", current.group()
        print "1st:", current.group(1)
        print "2nd:", current.group(2)
        print
    except:
        print " ", each
#        print re.split(r,each)
        print
# Out:
# ALL: 45 minutes
# 1st: 45
# 2nd: minutes
#
# ALL: 2 hrs
# 1st: 2
# 2nd: hrs
#
# ALL: 20 seconds
# 1st: 20
# 2nd: seconds
#
# ALL: 2 hour
# 1st: 2
# 2nd: hour
#
# ALL: 15 minutes
# 1st: 15
# 2nd: minutes
#
# ALL: 5 minutes
# 1st: 5
# 2nd: minutes
#
# ALL: 3 mins
# 1st: 3
# 2nd: mins
#
# ALL: 20 minutes
# 1st: 20
# 2nd: minutes
#
# ALL:   3  minutes
#
# ALL:   several minutes
#
# ALL: 5 min
# 1st: 5
# 2nd: min
#
# ALL: 3 minutes
# 1st: 3
# 2nd: minutes
#
# ALL: 30 min
# 1st: 30
# 2nd: min
#
# ALL: 3 minutes
# 1st: 3
# 2nd: minutes
#
# ALL: 30 seconds
# 1st: 30
# 2nd: seconds
#
# ALL:   20minutes
#
# ALL: 2 minutes
# 1st: 2
# 2nd: minutes
#
# ALL: 30 min
# 1st: 30
# 2nd: min
#
# ALL: 20 sec
# 1st: 20
# 2nd: sec
#
# ALL: 45 minutes
# 1st: 45
# 2nd: minutes
#
# ALL: 20 minutes
# 1st: 20
# 2nd: minutes
#
# ALL:   one hour?
#
# ALL: 6 minutes
# 1st: 6
# 2nd: minutes
#
# ALL: 1 minute
# 1st: 1
# 2nd: minute
#
# ALL: 3 seconds
# 1st: 3
# 2nd: seconds
#
# ALL: 30 seconds
# 1st: 30
# 2nd: seconds
#
# ALL: 30 seconds
# 1st: 30
# 2nd: seconds
#
# ALL:   5min
#
# ALL: 15 minutes
# 1st: 15
# 2nd: minutes
#
# ALL: 5 or
# 1st: 5
# 2nd: or
#
# ALL: 3 minutes
# 1st: 3
# 2nd: minutes
#
# ALL:   30mins.
#
# ALL: 3 min
# 1st: 3
# 2nd: min
#
# ALL: 5 minutes
# 1st: 5
# 2nd: minutes
#
# ALL: 3 to
# 1st: 3
# 2nd: to
#
# ALL:   2min
#
# ALL: 1 minute
# 1st: 1
# 2nd: minute
#
# ALL:   couple minutes
#
# ALL: 20 seconds
# 1st: 20
# 2nd: seconds
#
# ALL:   10min
#
# ALL: 3 minutes
# 1st: 3
# 2nd: minutes
#
# ALL: 10 minutes
# 1st: 10
# 2nd: minutes
#
# ALL:   few minutes
#
# ALL: 1 minute
# 1st: 1
# 2nd: minute
#
# ALL: 2 sec
# 1st: 2
# 2nd: sec
#
# ALL: 5 min
# 1st: 5
# 2nd: min
#
# ALL: 1 minute
# 1st: 1
# 2nd: minute
#
# ALL:   3min
#
# ALL: 2 minutes
# 1st: 2
# 2nd: minutes
#
# ALL: 30 minutes
# 1st: 30
# 2nd: minutes
#
# ALL: 10 minutes
# 1st: 10
# 2nd: minutes
#
# ALL: 1 hour
# 1st: 1
# 2nd: hour
#
# ALL: 10 seconds
# 1st: 10
# 2nd: seconds
#
# ALL:   1min. 39s
#
# ALL: 30 seconds
# 1st: 30
# 2nd: seconds
#
# ALL: 20 minutes
# 1st: 20
# 2nd: minutes
#
# ALL: 8 seconds
# 1st: 8
# 2nd: seconds
#
# ALL: 1 min
# 1st: 1
# 2nd: min
#
# ALL: 1 hour
# 1st: 1
# 2nd: hour
#
# ALL: 2 minutes
# 1st: 2
# 2nd: minutes
#
# ALL: 5 seconds
# 1st: 5
# 2nd: seconds
#
# ALL: 1 hour
# 1st: 1
# 2nd: hour
#
# ALL: 2 min
# 1st: 2
# 2nd: min
#
# ALL: 1 minute
# 1st: 1
# 2nd: minute
#
# ALL:   3sec
#
# ALL: 5 min
# 1st: 5
# 2nd: min
#
# ALL: 5 min
# 1st: 5
# 2nd: min
#
# ALL: 1 minute
# 1st: 1
# 2nd: minute
#
# ALL: 4 hours
# 1st: 4
# 2nd: hours
#
# ALL: 30 seconds
# 1st: 30
# 2nd: seconds
#
# ALL: 5 minutes
# 1st: 5
# 2nd: minutes
#
# ALL:   1-hour
#
# ALL: 5 minutes
# 1st: 5
# 2nd: minutes
#
# ALL: 10 to
# 1st: 10
# 2nd: to
#
# ALL:   30 +/- min
#
# ALL: 10 minutes
# 1st: 10
# 2nd: minutes
#
# ALL:   45min.
#
# ALL: 1 min
# 1st: 1
# 2nd: min
#
# ALL: 10 minutes
# 1st: 10
# 2nd: minutes
#
# ALL: 2 seconds
# 1st: 2
# 2nd: seconds
#
# ALL: 2 hours
# 1st: 2
# 2nd: hours
#
# ALL: 15 seconds
# 1st: 15
# 2nd: seconds
#
# ALL: 1 hour
# 1st: 1
# 2nd: hour
#
# ALL: 10 min
# 1st: 10
# 2nd: min
#
# ALL: 10 seconds
# 1st: 10
# 2nd: seconds
#
# ALL: 1 hour
# 1st: 1
# 2nd: hour
#
# ALL: 45 secs
# 1st: 45
# 2nd: secs
#
# ALL: 90 sec
# 1st: 90
# 2nd: sec
#
# ALL: 3 hours
# 1st: 3
# 2nd: hours
#
# ALL: 5 min
# 1st: 5
# 2nd: min
#
# ALL:   several minutes
#
# ALL: 4 minutes
# 1st: 4
# 2nd: minutes
#
# ALL: 45 minutes
# 1st: 45
# 2nd: minutes
#
# ALL: 3 minutes
# 1st: 3
# 2nd: minutes
#
# ALL: 10 seconds
# 1st: 10
# 2nd: seconds
#
# ALL:   30seconds
#
# ALL: 45 seconds
# 1st: 45
# 2nd: seconds
#
# ALL: 15 seconds
# 1st: 15
# 2nd: seconds
#
# ALL: 30 min
# 1st: 30
# 2nd: min
#
# ALL: 5 seconds
# 1st: 5
# 2nd: seconds

# %% [markdown]
# Here are the **"rules" and guiding principles** for this assignment:
#
# - The normalized duration does not have to be exactly correct, but it must be at least **within the given range**. For example:
#     - If the duration is '20-30 min', acceptable answers include '20 min' and '30 min'.
#     - If the duration is '1/2 hour', the only acceptable answer is '0.5 hr'.
# - When a number is not given, you should make a **"reasonable" substitution for the words**. For example:
#     - If the duration is 'several minutes', you can approximate this as '5 min'.
#     - If the duration is 'couple minutes', you can approximate this as '2 min'.
# - You are not allowed to **skip any entries**. (Your list of tuples should have a length of 100.)
# - Try to use **as few substitutions as possible**, and make your regular expression **as simple as possible**.
# - Just because you don't get an error doesn't mean that your code was successful. Instead, you should **check each entry by hand** to see if it produced an acceptable result.

# %% [markdown]
# **Bonus tasks:**
#
# - Try reading in **more than 100 rows**, and see if your code still produces the correct results.
# - When a range is specified (such as '1-2 hrs' or '10 to 15 sec'), **calculate the exact midpoint** ('1.5 hr' or '12.5 sec') to use in your normalized data.
